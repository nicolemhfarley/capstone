# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from statsmodels.graphics import tsaplots
import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARIMA, ARIMAResults, ARMA
from statsmodels.tsa.arima_process import ArmaProcess
from sklearn.metrics import mean_squared_error
# %load_ext autoreload
# %autoreload 2
import warnings
warnings.filterwarnings("ignore")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from timeseries_functions import index_to_datetime, plot_all_df_columns, weekly_resample, plot_series,\
plot_series_save_fig, plot_series_and_differences, run_augmented_Dickey_Fuller_test, \
plot_autocorrelation, plot_partial_autocorrelation, plot_decomposition

# %%
# import data for 2018
df_2018 = pd.read_csv('./data/AppointmentsSince2018.csv')

# %%
df_2018.head().T
# Out:
#                                                0                    1  \
# id                                       1780964              1782785
# Patient                              3.11448e+08          3.11612e+08
# PatientAgeMeetingDate                         15                   37
# PatientGender                                  F                    M
# PatientState                                  CA                   CA
# PatientCity                                  928                  946
# PatientInsurance         Blue Cross - California  Blue Shield PPO/HMO
# Provider                                      10                   13
# Specialty                             Psychiatry  Physician Assistant
# AppointmentDate              2018-08-29 16:00:00  2018-08-29 16:00:00
# AppointmentDuration                           60                   30
# AppointmentCreated           2018-05-29 17:33:00  2018-05-30 17:37:00
# MeetingReasonForVisitId                        9                    6
# MeetingStatusId                                1                    1
# OfficeId                                       3                    7
# CreatedBy                                     72                   25
#
#                                            2                    3  \
# id                                   1782784              1782783
# Patient                          3.11572e+08          3.10877e+08
# PatientAgeMeetingDate                     24                   39
# PatientGender                              F                    F
# PatientState                              CA                   CA
# PatientCity                              900                  902
# PatientInsurance              Anthem PPO/HMO            Aetna PPO
# Provider                                  13                   13
# Specialty                Physician Assistant  Physician Assistant
# AppointmentDate          2018-08-29 12:00:00  2018-08-29 11:00:00
# AppointmentDuration                       30                   30
# AppointmentCreated       2018-05-30 14:39:00  2018-05-23 11:02:00
# MeetingReasonForVisitId                    6                    6
# MeetingStatusId                            1                    1
# OfficeId                                   7                    7
# CreatedBy                                 25                   25
#
#                                            4
# id                                   1783013
# Patient                          3.11623e+08
# PatientAgeMeetingDate                     38
# PatientGender                              F
# PatientState                              CA
# PatientCity                              913
# PatientInsurance           Blue Shield of CA
# Provider                                  15
# Specialty                Physician Assistant
# AppointmentDate          2018-08-29 11:00:00
# AppointmentDuration                       45
# AppointmentCreated       2018-05-30 19:37:00
# MeetingReasonForVisitId                    4
# MeetingStatusId                            1
# OfficeId                                   8
# CreatedBy                                  8

# %%
df_2018['Specialty'].value_counts()
# Out:
# Psych/Mental Health                        3342
# Physician Assistant                        2672
# Medical                                    2382
# Marriage & Family Therapist                1389
# Child & Adolescent Psychiatry              1215
# Psychiatry                                  987
# Psych/Mental Health, Child & Adolescent     979
# Specialist/Technologist, Other              528
# Psychologist                                180
# Name: Specialty, dtype: int64

# %%
df_2018.columns
# Out:
# Index(['id', 'Patient', 'PatientAgeMeetingDate', 'PatientGender',
#        'PatientState', 'PatientCity', 'PatientInsurance', 'Provider',
#        'Specialty', 'AppointmentDate', 'AppointmentDuration',
#        'AppointmentCreated', 'MeetingReasonForVisitId', 'MeetingStatusId',
#        'OfficeId', 'CreatedBy'],
#       dtype='object')

# %%
# keep only relevant columns
df_2018 = df_2018[['Specialty', 'AppointmentDate', 'AppointmentDuration']]

# %%
# set appoinmtemnt duration column to hours
df_2018['AppointmentDurationHours'] = df_2018['AppointmentDuration'] / 60.0

# %%
df_2018.head()
# Out:
#              Specialty      AppointmentDate  AppointmentDuration  \
# 0           Psychiatry  2018-08-29 16:00:00                   60
# 1  Physician Assistant  2018-08-29 16:00:00                   30
# 2  Physician Assistant  2018-08-29 12:00:00                   30
# 3  Physician Assistant  2018-08-29 11:00:00                   30
# 4  Physician Assistant  2018-08-29 11:00:00                   45
#
#    AppointmentDurationHours
# 0                      1.00
# 1                      0.50
# 2                      0.50
# 3                      0.50
# 4                      0.75

# %%
#separate by specialty
doctors = ['Psychiatry', 'Child & Adolescent Psychiatry', ]
RN_PAs = ['Medical', 'Psych/Mental Health, Child & Adolescent', 'Psych/Mental Health', 'Physician Assistant']
therapists = ['Marriage & Family Therapist', 'Psychologist', 'Specialist/Technologist, Other', 'Clinical' ]

# %%
df_2018['Specialty'].loc[df_2018['Specialty'].isin(doctors)]= 'doctor'
df_2018['Specialty'].loc[df_2018['Specialty'].isin(RN_PAs)] = 'RN/PA'
df_2018['Specialty'].loc[df_2018['Specialty'].isin(therapists)] = 'therapist'

# %%
df_2018['Specialty'].value_counts()
# Out:
# RN/PA        9375
# doctor       2202
# therapist    2097
# Name: Specialty, dtype: int64

# %%
df_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13815 entries, 0 to 13814
# Data columns (total 4 columns):
# Specialty                   13674 non-null object
# AppointmentDate             13815 non-null object
# AppointmentDuration         13815 non-null int64
# AppointmentDurationHours    13815 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 431.8+ KB

# %%
# convert Appointmentdate column to datetime then set as index
df_2018['AppointmentDate'] = pd.to_datetime(df_2018['AppointmentDate'], format='%Y-%m-%d', errors='coerce')

# %%
df_2018.index = df_2018['AppointmentDate']

# %%
df_2018.index
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-08', '2018-01-15', '2018-01-22',
#                '2018-01-29', '2018-02-05', '2018-02-12', '2018-02-19',
#                '2018-02-26', '2018-03-05', '2018-03-12', '2018-03-19',
#                '2018-03-26', '2018-04-02', '2018-04-09', '2018-04-16',
#                '2018-04-23', '2018-04-30', '2018-05-07', '2018-05-14',
#                '2018-05-21', '2018-05-28', '2018-06-04', '2018-06-11',
#                '2018-06-18', '2018-06-25', '2018-07-02', '2018-07-09',
#                '2018-07-16', '2018-07-23', '2018-07-30', '2018-08-06',
#                '2018-08-13', '2018-08-20', '2018-08-27', '2018-09-03'],
#               dtype='datetime64[ns]', name='AppointmentDate', freq='W-MON')

# %%
# resample to weekly data
df_2018 = df_2018.resample('W-MON').sum()

# %%
df_2018.head()
# Out:
#                  AppointmentDuration  AppointmentDurationHours
# AppointmentDate
# 2018-01-01                        60                  1.000000
# 2018-01-08                     26895                448.250000
# 2018-01-15                     29655                494.250000
# 2018-01-22                     28350                472.500000
# 2018-01-29                     26495                441.583333

# %%
df_2018
# Out:
#                  AppointmentDuration  AppointmentDurationHours
# AppointmentDate
# 2018-01-01                        60                  1.000000
# 2018-01-08                     26895                448.250000
# 2018-01-15                     29655                494.250000
# 2018-01-22                     28350                472.500000
# 2018-01-29                     26495                441.583333
# 2018-02-05                     26235                437.250000
# 2018-02-12                     26115                435.250000
# 2018-02-19                     20715                345.250000
# 2018-02-26                     29010                483.500000
# 2018-03-05                     26630                443.833333
# 2018-03-12                     27060                451.000000
# 2018-03-19                     30600                510.000000
# 2018-03-26                     30090                501.500000
# 2018-04-02                     26865                447.750000
# 2018-04-09                     29950                499.166667
# 2018-04-16                     25485                424.750000
# 2018-04-23                     26540                442.333333
# 2018-04-30                     26680                444.666667
# 2018-05-07                     27840                464.000000
# 2018-05-14                     27555                459.250000
# 2018-05-21                     28005                466.750000
# 2018-05-28                     20460                341.000000
# 2018-06-04                     28875                481.250000
# 2018-06-11                     23730                395.500000
# 2018-06-18                     18285                304.750000
# 2018-06-25                     12270                204.500000
# 2018-07-02                      8130                135.500000
# 2018-07-09                      3195                 53.250000
# 2018-07-16                      2820                 47.000000
# 2018-07-23                      1635                 27.250000
# 2018-07-30                      1005                 16.750000
# 2018-08-06                      1020                 17.000000
# 2018-08-13                       585                  9.750000
# 2018-08-20                       495                  8.250000
# 2018-08-27                       405                  6.750000
# 2018-09-03                       255                  4.250000

# %%
may_2018 = df_2018['2018-04-30':'2018-06-04']

# %%
may_2018
# Out:
#                  AppointmentDuration  AppointmentDurationHours
# AppointmentDate
# 2018-04-30                     26680                444.666667
# 2018-05-07                     27840                464.000000
# 2018-05-14                     27555                459.250000
# 2018-05-21                     28005                466.750000
# 2018-05-28                     20460                341.000000
# 2018-06-04                     28875                481.250000
